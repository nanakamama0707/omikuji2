# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 18.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 16.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 2.9 MB/s eta 0:00:00
# ...

# %%
import os
os.chdir('/content/drive/MyDrive/ikoma/omikuji')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ddc9b2925c2a> in <cell line: 2>()
#       1 import os
# ----> 2 os.chdir('/content/drive/MyDrive/ikoma/omikuji')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/ikoma/omikuji'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
files.view("omikuji.py")

# %%
# !streamlit run omikuji.py & sleep 3 && npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.168.221.186:8501
#
# npx: installed 22 in 2.004s
# your url is: https://dark-peas-guess.loca.lt
# 2024-06-05 04:57:47.792 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/content/drive/MyDrive/ikoma/omikuji.py", line 6, in <module>
#     name = st.sidebar.text_input()
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/metrics_util.py", line 397, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
# TypeError: TextWidgetsMixin.text_input() missing 1 required positional argument: 'label'
# 2024-06-05 05:04:01.852 Uncaught app exception
# Traceback (most recent call last):
# ...
